# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/날씨데이터 콘테스트/가공 data/final_data.csv')
df
# Out:
# <ipython-input-3-082078194da7>:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/날씨데이터 콘테스트/가공 data/final_data.csv')
#         Unnamed: 0.1  Unnamed: 0  num                 time      latitude  \
# 0                  0           0    1  2021-01-08 00:39:00  "N35.063823"
# 1                  1           1    1  2021-01-08 00:39:00  "N35.063828"
# 2                  2           2    1  2021-01-08 00:39:00  "N35.063833"
# 3                  3           3    1  2021-01-08 00:39:00  "N35.063847"
# 4                  4           4    1  2021-01-08 00:39:00  "N35.063862"
# ...              ...         ...  ...                  ...           ...
# 681160        217698      217698  163  2022-06-20 19:45:00  "N35.441047"
# 681161        217699      217699  163  2022-06-20 19:48:00  "N35.441098"
# 681162        217700      217700  163  2022-06-20 19:51:00  "N35.441150"
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681165 entries, 0 to 681164
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0.1      681165 non-null  int64
#  1   Unnamed: 0        681165 non-null  int64
#  2   num               681165 non-null  int64
#  3   time              681165 non-null  object
#  4   latitude          681165 non-null  object
#  5   longitude         681165 non-null  object
#  6   sog               681165 non-null  float64
#  7   cog               681165 non-null  float64
#  8   hdg               681165 non-null  object
#  9   pagobuoy_max_wh   681165 non-null  float64
#  10  pagobuoy_sig_wh   681165 non-null  float64
#  11  pagobuoy_mean_wh  681165 non-null  float64
#  12  stn               681165 non-null  int64
#  13  stn_name          681165 non-null  object
#  14  lightbecon_wd     681165 non-null  int64
#  15  lightbecon_ws     681165 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1        0
# Unnamed: 0          0
# num                 0
# time                0
# latitude            0
# longitude           0
# sog                 0
# cog                 0
# hdg                 0
# pagobuoy_max_wh     0
# pagobuoy_sig_wh     0
# pagobuoy_mean_wh    0
# stn                 0
# stn_name            0
# lightbecon_wd       0
# lightbecon_ws       0
# buoy_ws             0
# buoy_wd             0
# answer              0
# location            0
# dtype: int64

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# 단색 산점도 행렬 (종속변수를 함께 그릴 때 유용)

scatter_matrix( df, alpha = 0.5, figsize = (8, 8),
																	diagonal = 'hist' )
plt.show()

# %%
df.describe()
# Out:
#         Unnamed: 0.1     Unnamed: 0            num            sog  \
# count  681165.000000  681165.000000  681165.000000  681165.000000
# mean    96834.812759   96834.812759      61.242614       0.250899
# std     62293.734938   62293.734938      37.812492       1.349804
# min         0.000000       0.000000       1.000000       0.000000
# 25%     42572.000000   42572.000000      33.000000       0.100000
# 50%     90966.000000   90966.000000      54.000000       0.100000
# 75%    147730.000000  147730.000000      85.000000       0.200000
# max    226396.000000  226396.000000     163.000000     102.300000
#
#                  cog  pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  \
# count  681165.000000    681165.000000    681165.000000     681165.000000
# mean      181.107776         0.919440         0.617121          0.336661
# std       107.755274         2.963847         2.924979          2.898761
# min       -99.900000       -49.550000       -49.650000        -49.750000
# ...

# %%
df[df['cog'] == -99.900000]
# Out:
#         Unnamed: 0.1  Unnamed: 0  num                 time      latitude  \
# 0                  0           0    1  2021-01-08 00:39:00  "N35.063823"
# 1                  1           1    1  2021-01-08 00:39:00  "N35.063828"
# 2                  2           2    1  2021-01-08 00:39:00  "N35.063833"
# 3                  3           3    1  2021-01-08 00:39:00  "N35.063847"
# 4                  4           4    1  2021-01-08 00:39:00  "N35.063862"
# ...              ...         ...  ...                  ...           ...
# 622376        158914      158914  102  2021-11-29 17:35:00  "N35.448335"
# 622518        159056      159056  102  2021-11-29 18:11:00  "N35.448240"
# 623737        160275      160275  102  2021-11-30 01:29:00  "N35.448153"
# 624363        160901      160901  102  2021-11-30 05:26:00  "N35.448342"
# 666826        203364      203364  150  2022-04-28 19:12:00  "N35.426283"
#
#             longitude    sog   cog    hdg  pagobuoy_max_wh  pagobuoy_sig_wh  \
# ...

# %%
df.sort_values(by='time')
# Out:
#         Unnamed: 0.1  Unnamed: 0  num                 time      latitude  \
# 6066            6066        6066   12  2021-01-01 11:34:17  "N35.032583"
# 6067            6067        6067   12  2021-01-01 11:34:38  "N35.032627"
# 6068            6068        6068   12  2021-01-01 11:34:46  "N35.032647"
# 6069            6069        6069   12  2021-01-01 11:34:56  "N35.032667"
# 6070            6070        6070   12  2021-01-01 11:35:07  "N35.032685"
# ...              ...         ...  ...                  ...           ...
# 681102        217640      217640  163  2022-06-24 06:44:00  "N35.443685"
# 681105        217643      217643  163  2022-06-24 06:44:00  "N35.443428"
# 681104        217642      217642  163  2022-06-24 06:44:00  "N35.443515"
# 681101        217639      217639  163  2022-06-24 06:44:00  "N35.443755"
# 681103        217641      217641  163  2022-06-24 06:44:00  "N35.443608"
#
#             longitude  sog    cog    hdg  pagobuoy_max_wh  pagobuoy_sig_wh  \
# ...

# %% [markdown]
# ### 위도와 경도에 따라서 닻끌림이 어떻게 발생했는지 scatter plot을 통해 그 지역별 분포를 봐보도록 하겠다.

# %%
df['latitude'] = df['latitude'].str[2:-1]
df['longitude'] = df['longitude'].str[2:-1]

# %%
sns.set_style('whitegrid')
sns.scatterplot(data=df[['latitude', 'longitude', 'answer']], x='latitude', y='longitude',
                hue='answer', ## 각 요일별로 색상이 다르게 그려진다. ## 일, 토, 목, 금 순으로 색상과 범례가 표시
               )
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>
# Error in callback <function _draw_all_if_interactive at 0x7fdffc3960e0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#     121
#     122
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080         if not self._is_idle_drawing:
# ...

# %%
df1  = df[df['location'] == 0]

# %%
sns.set_style('whitegrid')
sns.scatterplot(data=df1[['latitude', 'longitude', 'answer']], x='latitude', y='longitude',
                hue='answer', ## 각 요일별로 색상이 다르게 그려진다. ## 일, 토, 목, 금 순으로 색상과 범례가 표시
               )
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Error in callback <function flush_figures at 0x7fdffc395360> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
# ...

# %%
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  num                 time   latitude  \
# 0                  0           0    1  2021-01-08 00:39:00  35.063823
# 1                  1           1    1  2021-01-08 00:39:00  35.063828
# 2                  2           2    1  2021-01-08 00:39:00  35.063833
# 3                  3           3    1  2021-01-08 00:39:00  35.063847
# 4                  4           4    1  2021-01-08 00:39:00  35.063862
# ...              ...         ...  ...                  ...        ...
# 681160        217698      217698  163  2022-06-20 19:45:00  35.441047
# 681161        217699      217699  163  2022-06-20 19:48:00  35.441098
# 681162        217700      217700  163  2022-06-20 19:51:00  35.441150
# 681163        217701      217701  163  2022-06-20 19:54:00  35.441153
# 681164        217702      217702  163  2022-06-20 19:57:00  35.441000
#
#          longitude  sog    cog    hdg  pagobuoy_max_wh  pagobuoy_sig_wh  \
# ...

# %%
df = df.drop(['Unnamed: 0.1', 'Unnamed: 0', 'stn_name'],axis=1)

# %%
df.info()
df['time'] = pd.to_datetime(df['time'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681165 entries, 0 to 681164
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   num               681165 non-null  int64
#  1   time              681165 non-null  object
#  2   latitude          681165 non-null  object
#  3   longitude         681165 non-null  object
#  4   sog               681165 non-null  float64
#  5   cog               681165 non-null  float64
#  6   hdg               681165 non-null  object
#  7   pagobuoy_max_wh   681165 non-null  float64
#  8   pagobuoy_sig_wh   681165 non-null  float64
#  9   pagobuoy_mean_wh  681165 non-null  float64
#  10  stn               681165 non-null  int64
#  11  lightbecon_wd     681165 non-null  int64
#  12  lightbecon_ws     681165 non-null  float64
#  13  buoy_ws           681165 non-null  float64
#  14  buoy_wd           681165 non-null  float64
# ...

# %%
plt.plot(df['time'], df['pagobuoy_max_wh'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681165 entries, 0 to 681164
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   num               681165 non-null  int64
#  1   time              681165 non-null  datetime64[ns]
#  2   latitude          681165 non-null  object
#  3   longitude         681165 non-null  object
#  4   sog               681165 non-null  float64
#  5   cog               681165 non-null  float64
#  6   hdg               681165 non-null  object
#  7   pagobuoy_max_wh   681165 non-null  float64
#  8   pagobuoy_sig_wh   681165 non-null  float64
#  9   pagobuoy_mean_wh  681165 non-null  float64
#  10  stn               681165 non-null  int64
#  11  lightbecon_wd     681165 non-null  int64
#  12  lightbecon_ws     681165 non-null  float64
#  13  buoy_ws           681165 non-null  float64
#  14  buoy_wd           681165 non-null  float64
# ...

# %%
df['latitude'] = df['latitude'].astype('float')
df['longitude'] = df['longitude'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-35c73331b6cf> in <cell line: 4>()
#       2 df['longitude'] = df['longitude'].astype('float')
#       3 df['hdg'] = df['hdg'].replace('"','')
# ----> 4 df['hdg'] = df['hdg'].astype('float')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
df
# Out:
#         num                time   latitude   longitude  sog    cog    hdg  \
# 0         1 2021-01-08 00:39:00  35.063823  129.053027  0.1  -99.9  "344"
# 1         1 2021-01-08 00:39:00  35.063828  129.053030  0.2  -99.9  "342"
# 2         1 2021-01-08 00:39:00  35.063833  129.053032  0.2  -99.9  "339"
# 3         1 2021-01-08 00:39:00  35.063847  129.053033  0.1  -99.9  "337"
# 4         1 2021-01-08 00:39:00  35.063862  129.053032  0.2  -99.9  "336"
# ...     ...                 ...        ...         ...  ...    ...    ...
# 681160  163 2022-06-20 19:45:00  35.441047  129.414943  0.1  350.3    280
# 681161  163 2022-06-20 19:48:00  35.441098  129.414933  0.0   43.3    273
# 681162  163 2022-06-20 19:51:00  35.441150  129.415073  0.1   80.4    274
# 681163  163 2022-06-20 19:54:00  35.441153  129.415282  0.2   95.3    275
# 681164  163 2022-06-20 19:57:00  35.441000  129.415387  0.2  185.3    282
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  stn  \
# ...

# %%
df['hdg'].str.replace('"','')
# Out:
# 0         344
# 1         342
# 2         339
# 3         337
# 4         336
#          ...
# 681160    NaN
# 681161    NaN
# 681162    NaN
# 681163    NaN
# 681164    NaN
# Name: hdg, Length: 681165, dtype: object

# %%
df[df['location'] == 1]['hdg'] = df[df['location'] == 1]['hdg'].astype('float')
# Out:
# <ipython-input-42-d83c3935a942>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['location'] == 1]['hdg'] = df[df['location'] == 1]['hdg'].astype('float')

# %%
df
# Out:
#         num                time   latitude   longitude  sog    cog    hdg  \
# 0         1 2021-01-08 00:39:00  35.063823  129.053027  0.1  -99.9  "344"
# 1         1 2021-01-08 00:39:00  35.063828  129.053030  0.2  -99.9  "342"
# 2         1 2021-01-08 00:39:00  35.063833  129.053032  0.2  -99.9  "339"
# 3         1 2021-01-08 00:39:00  35.063847  129.053033  0.1  -99.9  "337"
# 4         1 2021-01-08 00:39:00  35.063862  129.053032  0.2  -99.9  "336"
# ...     ...                 ...        ...         ...  ...    ...    ...
# 681160  163 2022-06-20 19:45:00  35.441047  129.414943  0.1  350.3    280
# 681161  163 2022-06-20 19:48:00  35.441098  129.414933  0.0   43.3    273
# 681162  163 2022-06-20 19:51:00  35.441150  129.415073  0.1   80.4    274
# 681163  163 2022-06-20 19:54:00  35.441153  129.415282  0.2   95.3    275
# 681164  163 2022-06-20 19:57:00  35.441000  129.415387  0.2  185.3    282
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  stn  \
# ...

# %%
df[df['location'] == 0]['hdg'].isin(['"'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 294074    False
# 294075    False
# 294076    False
# 294077    False
# 294078    False
# Name: hdg, Length: 294079, dtype: bool

# %%
df[df['location'] == 0]['hdg'].replace('"', ';')
# Out:
# 0         "344"
# 1         "342"
# 2         "339"
# 3         "337"
# 4         "336"
#           ...
# 294074      100
# 294075       92
# 294076       70
# 294077       66
# 294078       63
# Name: hdg, Length: 294079, dtype: object

# %%
def dequote(s):
    """
    If a string has single or double quotes around it, remove them.
    Make sure the pair of quotes match.
    If a matching pair of quotes is not found, return the string unchanged.
    """
    if type(s) == type(df['hdg'][1]) :
      if s[0] == '"' :
        s = s[1:-1]
        if s[0] == '-' :
          s = 999
          return s
    else :
      return s

# %%
df2 = df.copy()

# %%
df2['hdg'] = df2['hdg'].apply(dequote)

# %%
type(df['hdg'][1])
# Out:
# str

# %%
df2['hdg'].astype('float')
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 681160    280.0
# 681161    273.0
# 681162    274.0
# 681163    275.0
# 681164    282.0
# Name: hdg, Length: 681165, dtype: float64

# %%
df2['hdg']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 681160    280.0
# 681161    273.0
# 681162    274.0
# 681163    275.0
# 681164    282.0
# Name: hdg, Length: 681165, dtype: float64

# %%
df2['hdg'][~df2['hdg'].str[:].isnull()]
# Out:
# 0        "344"
# 1        "342"
# 2        "339"
# 3        "337"
# 4        "336"
#          ...
# 98299       60
# 98300       61
# 98301      110
# 98302       79
# 98303       81
# Name: hdg, Length: 98304, dtype: object

# %%
df
# Out:
#         num                time   latitude   longitude  sog    cog    hdg  \
# 0         1 2021-01-08 00:39:00  35.063823  129.053027  0.1  -99.9  "344"
# 1         1 2021-01-08 00:39:00  35.063828  129.053030  0.2  -99.9  "342"
# 2         1 2021-01-08 00:39:00  35.063833  129.053032  0.2  -99.9  "339"
# 3         1 2021-01-08 00:39:00  35.063847  129.053033  0.1  -99.9  "337"
# 4         1 2021-01-08 00:39:00  35.063862  129.053032  0.2  -99.9  "336"
# ...     ...                 ...        ...         ...  ...    ...    ...
# 681160  163 2022-06-20 19:45:00  35.441047  129.414943  0.1  350.3    280
# 681161  163 2022-06-20 19:48:00  35.441098  129.414933  0.0   43.3    273
# 681162  163 2022-06-20 19:51:00  35.441150  129.415073  0.1   80.4    274
# 681163  163 2022-06-20 19:54:00  35.441153  129.415282  0.2   95.3    275
# 681164  163 2022-06-20 19:57:00  35.441000  129.415387  0.2  185.3    282
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  stn  \
# ...

# %%
df = df.drop(['hdg'], axis=1)

# %%
df
# Out:
#         num                time   latitude   longitude  sog    cog  \
# 0         1 2021-01-08 00:39:00  35.063823  129.053027  0.1  -99.9
# 1         1 2021-01-08 00:39:00  35.063828  129.053030  0.2  -99.9
# 2         1 2021-01-08 00:39:00  35.063833  129.053032  0.2  -99.9
# 3         1 2021-01-08 00:39:00  35.063847  129.053033  0.1  -99.9
# 4         1 2021-01-08 00:39:00  35.063862  129.053032  0.2  -99.9
# ...     ...                 ...        ...         ...  ...    ...
# 681160  163 2022-06-20 19:45:00  35.441047  129.414943  0.1  350.3
# 681161  163 2022-06-20 19:48:00  35.441098  129.414933  0.0   43.3
# 681162  163 2022-06-20 19:51:00  35.441150  129.415073  0.1   80.4
# 681163  163 2022-06-20 19:54:00  35.441153  129.415282  0.2   95.3
# 681164  163 2022-06-20 19:57:00  35.441000  129.415387  0.2  185.3
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  stn  \
# 0                  0.75             0.45               0.3  984
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681165 entries, 0 to 681164
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   num               681165 non-null  int64
#  1   time              681165 non-null  datetime64[ns]
#  2   latitude          681165 non-null  object
#  3   longitude         681165 non-null  object
#  4   sog               681165 non-null  float64
#  5   cog               681165 non-null  float64
#  6   pagobuoy_max_wh   681165 non-null  float64
#  7   pagobuoy_sig_wh   681165 non-null  float64
#  8   pagobuoy_mean_wh  681165 non-null  float64
#  9   stn               681165 non-null  int64
#  10  lightbecon_wd     681165 non-null  int64
#  11  lightbecon_ws     681165 non-null  float64
#  12  buoy_ws           681165 non-null  float64
#  13  buoy_wd           681165 non-null  float64
#  14  answer            681165 non-null  int64
# ...

# %%
df['latitude'] = df['latitude'].astype('float')
df['longitude'] = df['longitude'].astype('float')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681165 entries, 0 to 681164
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   num               681165 non-null  int64
#  1   time              681165 non-null  datetime64[ns]
#  2   latitude          681165 non-null  float64
#  3   longitude         681165 non-null  float64
#  4   sog               681165 non-null  float64
#  5   cog               681165 non-null  float64
#  6   pagobuoy_max_wh   681165 non-null  float64
#  7   pagobuoy_sig_wh   681165 non-null  float64
#  8   pagobuoy_mean_wh  681165 non-null  float64
#  9   stn               681165 non-null  int64
#  10  lightbecon_wd     681165 non-null  int64
#  11  lightbecon_ws     681165 non-null  float64
#  12  buoy_ws           681165 non-null  float64
#  13  buoy_wd           681165 non-null  float64
#  14  answer            681165 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  num       latitude      longitude            sog  \
# count  681165.000000  681165.000000  681165.000000  681165.000000
# mean       61.242614      35.284149     129.269338       0.250899
# std        37.812492       0.195906       0.190803       1.349804
# min         1.000000      31.643657     128.334025       0.000000
# 25%        33.000000      35.064350     129.046233       0.100000
# 50%        54.000000      35.413257     129.400638       0.100000
# 75%        85.000000      35.447617     129.438245       0.200000
# max       163.000000      35.498083     129.527412     102.300000
#
#                  cog  pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  \
# count  681165.000000    681165.000000    681165.000000     681165.000000
# mean      181.107776         0.919440         0.617121          0.336661
# std       107.755274         2.963847         2.924979          2.898761
# min       -99.900000       -49.550000       -49.650000        -49.750000
# ...

# %% [markdown]
# ### 결측치가 cog에서, boy_ws엣 buoy_wd에서 발생하는 것으로 보인다.

# %%
import matplotlib.pyplot as plt
df.plot(kind='box',subplots=True,layout =(5,6),figsize=(10,10))
plt.tight_layout()
plt.show()

# %%
df = df.drop(df[df['cog'] == -99.900000].index)

# %%
df[df['buoy_ws'] == -999.000000]
# Out:
#         num                time   latitude   longitude  sog    cog  \
# 294235    1 2021-01-03 19:08:39  35.462648  129.438157  0.1  245.4
# 294236    1 2021-01-03 19:08:40  35.462648  129.438157  0.1  245.4
# 294504    1 2021-01-04 08:47:43  35.460667  129.438247  0.4  166.6
# 297339    2 2021-01-04 20:50:47  35.448230  129.420580  0.3  340.5
# 297340    3 2021-01-04 20:50:09  35.458020  129.415618  0.2   66.7
# ...     ...                 ...        ...         ...  ...    ...
# 677047  160 2022-06-22 14:59:13  35.457080  129.423518  0.2  301.9
# 677048  162 2022-06-22 14:59:01  35.396902  129.461208  0.0  295.4
# 677054  162 2022-06-22 14:40:58  35.396782  129.461485  0.0  297.0
# 677055  162 2022-06-22 14:49:55  35.396727  129.461580  0.0  297.0
# 677056  162 2022-06-22 14:49:58  35.396727  129.461580  0.0  297.0
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  stn  \
# 294235             1.00             0.70              0.45  963
# ...

# %% [markdown]
# ### buoys의 결측치의 경우 1/6 즉 16%정도 되기 때문에 음..그냥 제거하기 보다는 대치를 해야 더 좋을 것으로 보인다. 그냥 간편하게 mean 값으로 대치해 보도록 하겠다.

# %%
ws_index = df[df['buoy_ws'] == -999.000000].index

# %%
for i in ws_index :
  # df.loc[i,'buoy_ws'] = df['buoy_ws'].median()
  df.loc[i,'buoy_ws'] = 14.7

# %%
df['buoy_ws'].median()
# Out:
# 14.7

# %%
wd_index = df[df['buoy_wd'] == -999.000000].index

# %%
for i in wd_index :
  # df.loc[i,'buoy_ws'] = df['buoy_wd'].median()
  df.loc[i,'buoy_wd'] = 87.0

# %%
df['buoy_wd'].median()
# Out:
# 87.0

# %%
df.describe()
# Out:
#                  num       latitude      longitude            sog  \
# count  675808.000000  675808.000000  675808.000000  675808.000000
# mean       61.395223      35.285951     129.271036       0.236781
# std        37.888965       0.195593       0.190563       0.557092
# min         1.000000      31.643657     128.334025       0.000000
# 25%        33.000000      35.064850     129.046420       0.100000
# 50%        54.000000      35.413423     129.400700       0.100000
# 75%        86.000000      35.447703     129.438368       0.200000
# max       163.000000      35.498083     129.527412     102.300000
#
#                  cog  pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  \
# count  675808.000000    675808.000000    675808.000000     675808.000000
# mean      183.335270         0.928758         0.626264          0.345424
# std       105.225154         2.892765         2.853109          2.826430
# min         0.000000       -49.550000       -49.650000        -49.750000
# ...

# %%
import matplotlib.pyplot as plt
df.plot(kind='box',subplots=True,layout =(5,6),figsize=(10,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 우선 -99의 경우는 결측치가 아닌 실제 값일 수도 있으므로 그대로 들고가고 나머지 3개는 일단 -999값에 대해서 처리해주었다. wd,ws의 경우에는 너무 많아서 median값으로 대체해 주었다. 이제는 전처리가 끝났다고 판단하여 let's go에 있는 eda를 마저 진행해 보겠다.

# %%
df = df.sort_values(by='time')
timedeltas = df['time'].diff().dt.seconds.dropna()
display(timedeltas.describe())
print()
# Out:
# count    675807.000000
# mean         38.967609
# std         720.462859
# min           0.000000
# 25%           0.000000
# 50%           2.000000
# 75%          24.000000
# max       86220.000000
# Name: time, dtype: float64

# %%
import datetime

# %%
df2 = df.copy()

# %%
df2['value'] = df2['cog']

# %%
while True:
    time_list=[]
    for p in range(len(df2)-1):
      if (df2['time'].diff().dt.seconds.dropna()[p:p+1].values[0])/60 >=24 :
            for t in range(int((df2['time'][p+1]-df2['time'][p]).seconds/60)+int(
                    (df2['time'][p+1]-df2['time'][p]).days*24*60)-1):
                time_list.append(df2['time'][p]+datetime.timedelta(minutes=1*(t+1)))

            break

    length=len(time_list)
    input_date=time_list
    input_value=[np.nan for x in range(len(time_list))]
    new_data=pd.DataFrame({'time':input_date,
              'value':input_value
              })

    idx = p+1
    temp1 = df2[df2.index < idx]
    temp2 = df2[df2.index >= idx]
    df2 = temp1.append(new_data,ignore_index=True).append(temp2, ignore_index=True)
    idx=idx

    if length==0:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 276
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df2['time'][1:2]-df2['time'][0:1]
# Out:
# 6066   NaT
# 6067   NaT
# Name: time, dtype: timedelta64[ns]

# %%
df2['time'][0:1]
# Out:
# 6066   2021-01-01 11:34:17
# Name: time, dtype: datetime64[ns]

# %%
df2['time'][1:2]
# Out:
# 6067   2021-01-01 11:34:38
# Name: time, dtype: datetime64[ns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 675808 entries, 6066 to 681103
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   num               675808 non-null  int64
#  1   time              675808 non-null  datetime64[ns]
#  2   latitude          675808 non-null  float64
#  3   longitude         675808 non-null  float64
#  4   sog               675808 non-null  float64
#  5   cog               675808 non-null  float64
#  6   pagobuoy_max_wh   675808 non-null  float64
#  7   pagobuoy_sig_wh   675808 non-null  float64
#  8   pagobuoy_mean_wh  675808 non-null  float64
#  9   stn               675808 non-null  int64
#  10  lightbecon_wd     675808 non-null  int64
#  11  lightbecon_ws     675808 non-null  float64
#  12  buoy_ws           675808 non-null  float64
#  13  buoy_wd           675808 non-null  float64
#  14  answer            675808 non-null  int64
# ...

# %%
df['time'].diff().dt.seconds.dropna()[0:1] >= 20
# Out:
# 6067    True
# Name: time, dtype: bool

# %%
df['time'].diff().dt.seconds.dropna()[0:1].values[0]
# Out:
# 21.0

# %%
(df2['time'].iloc[1] - df2['time'].iloc[0]).seconds
# Out:
# 21

# %% [markdown]
# ### 연속적인 데이터에서 발생하는 결측치를 해결하는 방법에 대해 처리하는 방법을 찾지 못하였다. 음... 일단 이건 결측치가 있다 정도로만 넘어가고

# %%
df2 = df.copy()
df2['value'] = df2['cog']

# %%
while True:
    time_list=[]
    for p in range(len(df2)-1):
      if (df2['time'].iloc[p+1]-df2['time'].iloc[p]).seconds/60 >=1400 :
            for t in range(int((df2['time'].iloc[p+1]-df2['time'].iloc[p]).seconds/60)+int(
                    (df2['time'].iloc[p+1]-df2['time'].iloc[p]).days*24*60)-1):
                time_list.append(df2['time'].iloc[p]+datetime.timedelta(minutes=1*(t+1)))

            break

    length=len(time_list)
    input_date=time_list
    input_value=[np.nan for x in range(len(time_list))]
    new_data=pd.DataFrame({'time':input_date,
              'value':input_value
              })

    idx = p+1
    temp1 = df2[df2.index < idx]
    temp2 = df2[df2.index >= idx]
    df2 = temp1.append(new_data,ignore_index=True).append(temp2, ignore_index=True)
    idx=idx

    if length==0:
        break
# Out:
# <ipython-input-164-41a94a186cd5>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = temp1.append(new_data,ignore_index=True).append(temp2, ignore_index=True)
# <ipython-input-164-41a94a186cd5>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = temp1.append(new_data,ignore_index=True).append(temp2, ignore_index=True)
# <ipython-input-164-41a94a186cd5>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = temp1.append(new_data,ignore_index=True).append(temp2, ignore_index=True)
# <ipython-input-164-41a94a186cd5>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df2
# Out:
#           num                time   latitude   longitude  sog    cog  \
# 0        12.0 2021-01-01 11:34:17  35.032583  129.049010  0.8   57.1
# 1        12.0 2021-01-01 11:34:38  35.032627  129.049060  0.6   46.4
# 2        12.0 2021-01-01 11:34:46  35.032647  129.049073  0.5   39.7
# 3        12.0 2021-01-01 11:34:56  35.032667  129.049083  0.4   27.5
# 4        12.0 2021-01-01 11:35:07  35.032685  129.049085  0.3   10.7
# ...       ...                 ...        ...         ...  ...    ...
# 697233  163.0 2022-06-24 06:44:00  35.443685  129.414905  1.4  187.5
# 697234  163.0 2022-06-24 06:44:00  35.443428  129.414842  2.0  193.2
# 697235  163.0 2022-06-24 06:44:00  35.443515  129.414872  1.8  188.1
# 697236  163.0 2022-06-24 06:44:00  35.443755  129.414917  1.1  186.0
# 697237  163.0 2022-06-24 06:44:00  35.443608  129.414883  1.6  193.8
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh    stn  \
# 0                   0.6             0.45              0.30  984.0
# ...

# %%
df
# Out:
#         num                time   latitude   longitude  sog    cog  \
# 6066     12 2021-01-01 11:34:17  35.032583  129.049010  0.8   57.1
# 6067     12 2021-01-01 11:34:38  35.032627  129.049060  0.6   46.4
# 6068     12 2021-01-01 11:34:46  35.032647  129.049073  0.5   39.7
# 6069     12 2021-01-01 11:34:56  35.032667  129.049083  0.4   27.5
# 6070     12 2021-01-01 11:35:07  35.032685  129.049085  0.3   10.7
# ...     ...                 ...        ...         ...  ...    ...
# 681102  163 2022-06-24 06:44:00  35.443685  129.414905  1.4  187.5
# 681105  163 2022-06-24 06:44:00  35.443428  129.414842  2.0  193.2
# 681104  163 2022-06-24 06:44:00  35.443515  129.414872  1.8  188.1
# 681101  163 2022-06-24 06:44:00  35.443755  129.414917  1.1  186.0
# 681103  163 2022-06-24 06:44:00  35.443608  129.414883  1.6  193.8
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  stn  \
# 6066                0.6             0.45              0.30  984
# ...

# %%
df2[df2.isnull()]
# Out:
#         num time  latitude  longitude  sog  cog  pagobuoy_max_wh  \
# 0       NaN  NaT       NaN        NaN  NaN  NaN              NaN
# 1       NaN  NaT       NaN        NaN  NaN  NaN              NaN
# 2       NaN  NaT       NaN        NaN  NaN  NaN              NaN
# 3       NaN  NaT       NaN        NaN  NaN  NaN              NaN
# 4       NaN  NaT       NaN        NaN  NaN  NaN              NaN
# ...     ...  ...       ...        ...  ...  ...              ...
# 697233  NaN  NaT       NaN        NaN  NaN  NaN              NaN
# 697234  NaN  NaT       NaN        NaN  NaN  NaN              NaN
# 697235  NaN  NaT       NaN        NaN  NaN  NaN              NaN
# 697236  NaN  NaT       NaN        NaN  NaN  NaN              NaN
# 697237  NaN  NaT       NaN        NaN  NaN  NaN              NaN
#
#         pagobuoy_sig_wh  pagobuoy_mean_wh  stn  lightbecon_wd  lightbecon_ws  \
# 0                   NaN               NaN  NaN            NaN            NaN
# ...

# %%
df2
# Out:
#           num                time   latitude   longitude  sog    cog  \
# 0        12.0 2021-01-01 11:34:17  35.032583  129.049010  0.8   57.1
# 1        12.0 2021-01-01 11:34:38  35.032627  129.049060  0.6   46.4
# 2        12.0 2021-01-01 11:34:46  35.032647  129.049073  0.5   39.7
# 3        12.0 2021-01-01 11:34:56  35.032667  129.049083  0.4   27.5
# 4        12.0 2021-01-01 11:35:07  35.032685  129.049085  0.3   10.7
# ...       ...                 ...        ...         ...  ...    ...
# 697233  163.0 2022-06-24 06:44:00  35.443685  129.414905  1.4  187.5
# 697234  163.0 2022-06-24 06:44:00  35.443428  129.414842  2.0  193.2
# 697235  163.0 2022-06-24 06:44:00  35.443515  129.414872  1.8  188.1
# 697236  163.0 2022-06-24 06:44:00  35.443755  129.414917  1.1  186.0
# 697237  163.0 2022-06-24 06:44:00  35.443608  129.414883  1.6  193.8
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh    stn  \
# 0                   0.6             0.45              0.30  984.0
# ...

# %%
df2[df2['value'].isnull()]
# Out:
#         num                time  latitude  longitude  sog  cog  \
# 1580    NaN 2021-01-02 09:45:00       NaN        NaN  NaN  NaN
# 1581    NaN 2021-01-02 09:46:00       NaN        NaN  NaN  NaN
# 1582    NaN 2021-01-02 09:47:00       NaN        NaN  NaN  NaN
# 1583    NaN 2021-01-02 09:48:00       NaN        NaN  NaN  NaN
# 1584    NaN 2021-01-02 09:49:00       NaN        NaN  NaN  NaN
# ...     ...                 ...       ...        ...  ...  ...
# 561718  NaN 2022-02-10 22:37:00       NaN        NaN  NaN  NaN
# 561719  NaN 2022-02-10 22:38:00       NaN        NaN  NaN  NaN
# 561720  NaN 2022-02-10 22:39:00       NaN        NaN  NaN  NaN
# 561721  NaN 2022-02-10 22:40:00       NaN        NaN  NaN  NaN
# 561722  NaN 2022-02-10 22:41:00       NaN        NaN  NaN  NaN
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  stn  \
# 1580                NaN              NaN               NaN  NaN
# 1581                NaN              NaN               NaN  NaN
# ...

# %%
timedeltas = df2['time'].diff().dt.seconds.dropna()
display(timedeltas.describe())
print()
# Out:
# count    697237.000000
# mean         39.628681
# std         678.111446
# min           0.000000
# 25%           0.000000
# 50%           3.000000
# 75%          50.000000
# max       83687.000000
# Name: time, dtype: float64

# %%
df2
# Out:
#           num                time   latitude   longitude  sog    cog  \
# 0        12.0 2021-01-01 11:34:17  35.032583  129.049010  0.8   57.1
# 1        12.0 2021-01-01 11:34:38  35.032627  129.049060  0.6   46.4
# 2        12.0 2021-01-01 11:34:46  35.032647  129.049073  0.5   39.7
# 3        12.0 2021-01-01 11:34:56  35.032667  129.049083  0.4   27.5
# 4        12.0 2021-01-01 11:35:07  35.032685  129.049085  0.3   10.7
# ...       ...                 ...        ...         ...  ...    ...
# 697233  163.0 2022-06-24 06:44:00  35.443685  129.414905  1.4  187.5
# 697234  163.0 2022-06-24 06:44:00  35.443428  129.414842  2.0  193.2
# 697235  163.0 2022-06-24 06:44:00  35.443515  129.414872  1.8  188.1
# 697236  163.0 2022-06-24 06:44:00  35.443755  129.414917  1.1  186.0
# 697237  163.0 2022-06-24 06:44:00  35.443608  129.414883  1.6  193.8
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh    stn  \
# 0                   0.6             0.45              0.30  984.0
# ...

# %%
df
# Out:
#         num                time   latitude   longitude  sog    cog  \
# 6066     12 2021-01-01 11:34:17  35.032583  129.049010  0.8   57.1
# 6067     12 2021-01-01 11:34:38  35.032627  129.049060  0.6   46.4
# 6068     12 2021-01-01 11:34:46  35.032647  129.049073  0.5   39.7
# 6069     12 2021-01-01 11:34:56  35.032667  129.049083  0.4   27.5
# 6070     12 2021-01-01 11:35:07  35.032685  129.049085  0.3   10.7
# ...     ...                 ...        ...         ...  ...    ...
# 681102  163 2022-06-24 06:44:00  35.443685  129.414905  1.4  187.5
# 681105  163 2022-06-24 06:44:00  35.443428  129.414842  2.0  193.2
# 681104  163 2022-06-24 06:44:00  35.443515  129.414872  1.8  188.1
# 681101  163 2022-06-24 06:44:00  35.443755  129.414917  1.1  186.0
# 681103  163 2022-06-24 06:44:00  35.443608  129.414883  1.6  193.8
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  stn  \
# 6066                0.6             0.45              0.30  984
# ...

# %% [markdown]
# ### 보간 처리 완성 다만 현재 84000 초 이상의 차이에서만 1분차이를 진해앻ㅆ으므로 다시 timedelta를 진행했을 때 83000이 나타났을 수 밖에 없다. 이거를 어떻게 할지는 좀더 고민해보자. 이후에는 fillna를 처리해주면 되늰데 음 그냥 이 시게열 데이터에서의 결측치는 넘어가는 것이 좋을 듯 싶다. 일단 어떻게 처리하는 지는 알수 있었다. 채우는 것 까지만 해보자

# %%
(int((df2['time'].iloc[1+1]-df2['time'].iloc[1]).seconds/60)+int(
                    (df2['time'].iloc[1+1]-df2['time'].iloc[1]).days*24*60)-1)
# Out:
# -1

# %%
(df2['time'].iloc[1+1]-df2['time'].iloc[1]).seconds/60
# Out:
# 0.13333333333333333

# %%
(df2['time'].iloc[1+1]-df2['time'].iloc[1]).seconds
# Out:
# 8

# %%
(df2['time'].iloc[1+1]-df2['time'].iloc[1]).days*24*60
# Out:
# 0

# %%
(df2['time'].iloc[1+1]-df2['time'].iloc[1]).days
# Out:
# 0

# %%
int((df2['time'].iloc[1+1]-df2['time'].iloc[1]).seconds/60)
# Out:
# 0

# %%
range(int((df['time'].iloc[148+1]-df['time'].iloc[1]).seconds/60)+int(
                    (df['time'].iloc[148+1]-df['time'].iloc[1]).days*24*60)-1)
# Out:
# range(0, 45)

# %%
            for t in range(int((df2['time'].iloc[p+1]-df2['time'].iloc[p]).seconds/60)+int(
                    (df2['time'].iloc[p+1]-df2['time'].iloc[p]).days*24*60)-1):
                time_list.append(df2['time'].iloc[p]+datetime.timedelta(minutes=1*(t+1)))

# %%
time_list = []
for t in range(int((df['time'].iloc[275+1]-df['time'].iloc[1]).seconds/60/60)+int(
                    (df['time'].iloc[275+1]-df['time'].iloc[1]).days*24)-1) :
  time_list.append(df['time'].iloc[275]+datetime.timedelta(hours=1*(t+1)))

# %%
time_list
# Out:
# [Timestamp('2021-01-01 19:03:31'),
#  Timestamp('2021-01-01 20:03:31'),
#  Timestamp('2021-01-01 21:03:31'),
#  Timestamp('2021-01-01 22:03:31'),
#  Timestamp('2021-01-01 23:03:31'),
#  Timestamp('2021-01-02 00:03:31'),
#  Timestamp('2021-01-02 01:03:31')]

# %%
while True:
    time_list=[]
    for p in range(len(df)-1):
      if (df['time'].iloc[p+1]-df['time'].iloc[p]).seconds/60 > 65 :
        print(p)
# Out:
# 275
# 308
# 1579
# 9293
# 9546
# 12271
# 12413
# 12576
# 13901
# 15095
# 18731
# 19405
# 20388
# 23420
# 24302
# 42040
# 42532
# 43043
# 44348
# 46238
# 51790
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-202-3c308207b1b9> in <cell line: 1>()
#       2     time_list=[]
#       3     for p in range(len(df)-1):
# ----> 4       if (df['time'].iloc[p+1]-df['time'].iloc[p]).seconds/60 > 65 :
#       5         print(p)
#
# KeyboardInterrupt:

# %%
df2 = df.copy()
df2['value'] = df2['cog']

# %%
while True:
    time_list=[]
    for p in range(len(df2)-1):
      if (df2['time'].iloc[p+1]-df2['time'].iloc[p]).seconds/60 >=1400 :
            for t in range(int((df2['time'].iloc[p+1]-df2['time'].iloc[p]).seconds/60/60)+int(
                    (df2['time'].iloc[p+1]-df2['time'].iloc[p]).days*24)-1):
                time_list.append(df2['time'].iloc[p]+datetime.timedelta(hours=1*(t+1)))

            break

    length=len(time_list)
    input_date=time_list
    input_value=[np.nan for x in range(len(time_list))]
    new_data=pd.DataFrame({'time':input_date,
              'value':input_value
              })

    idx = p+1
    temp1 = df2[df2.index < idx]
    temp2 = df2[df2.index >= idx]
    df2 = temp1.append(new_data,ignore_index=True).append(temp2, ignore_index=True)
    idx=idx

    if length==0:
        break
# Out:
# <ipython-input-208-2f05d3df15d8>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = temp1.append(new_data,ignore_index=True).append(temp2, ignore_index=True)
# <ipython-input-208-2f05d3df15d8>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = temp1.append(new_data,ignore_index=True).append(temp2, ignore_index=True)
# <ipython-input-208-2f05d3df15d8>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = temp1.append(new_data,ignore_index=True).append(temp2, ignore_index=True)
# <ipython-input-208-2f05d3df15d8>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df2
# Out:
#           num                time   latitude   longitude  sog    cog  \
# 0        12.0 2021-01-01 11:34:17  35.032583  129.049010  0.8   57.1
# 1        12.0 2021-01-01 11:34:38  35.032627  129.049060  0.6   46.4
# 2        12.0 2021-01-01 11:34:46  35.032647  129.049073  0.5   39.7
# 3        12.0 2021-01-01 11:34:56  35.032667  129.049083  0.4   27.5
# 4        12.0 2021-01-01 11:35:07  35.032685  129.049085  0.3   10.7
# ...       ...                 ...        ...         ...  ...    ...
# 676147  163.0 2022-06-24 06:44:00  35.443685  129.414905  1.4  187.5
# 676148  163.0 2022-06-24 06:44:00  35.443428  129.414842  2.0  193.2
# 676149  163.0 2022-06-24 06:44:00  35.443515  129.414872  1.8  188.1
# 676150  163.0 2022-06-24 06:44:00  35.443755  129.414917  1.1  186.0
# 676151  163.0 2022-06-24 06:44:00  35.443608  129.414883  1.6  193.8
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh    stn  \
# 0                   0.6             0.45              0.30  984.0
# ...

# %%
df
# Out:
#         num                time   latitude   longitude  sog    cog  \
# 6066     12 2021-01-01 11:34:17  35.032583  129.049010  0.8   57.1
# 6067     12 2021-01-01 11:34:38  35.032627  129.049060  0.6   46.4
# 6068     12 2021-01-01 11:34:46  35.032647  129.049073  0.5   39.7
# 6069     12 2021-01-01 11:34:56  35.032667  129.049083  0.4   27.5
# 6070     12 2021-01-01 11:35:07  35.032685  129.049085  0.3   10.7
# ...     ...                 ...        ...         ...  ...    ...
# 681102  163 2022-06-24 06:44:00  35.443685  129.414905  1.4  187.5
# 681105  163 2022-06-24 06:44:00  35.443428  129.414842  2.0  193.2
# 681104  163 2022-06-24 06:44:00  35.443515  129.414872  1.8  188.1
# 681101  163 2022-06-24 06:44:00  35.443755  129.414917  1.1  186.0
# 681103  163 2022-06-24 06:44:00  35.443608  129.414883  1.6  193.8
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  stn  \
# 6066                0.6             0.45              0.30  984
# ...

# %%
df2[df2['value'].isnull()]
# Out:
#         num                time  latitude  longitude  sog  cog  \
# 1580    NaN 2021-01-02 10:44:00       NaN        NaN  NaN  NaN
# 1581    NaN 2021-01-02 11:44:00       NaN        NaN  NaN  NaN
# 1582    NaN 2021-01-02 12:44:00       NaN        NaN  NaN  NaN
# 1583    NaN 2021-01-02 13:44:00       NaN        NaN  NaN  NaN
# 1584    NaN 2021-01-02 14:44:00       NaN        NaN  NaN  NaN
# ...     ...                 ...       ...        ...  ...  ...
# 540632  NaN 2022-02-10 17:13:00       NaN        NaN  NaN  NaN
# 540633  NaN 2022-02-10 18:13:00       NaN        NaN  NaN  NaN
# 540634  NaN 2022-02-10 19:13:00       NaN        NaN  NaN  NaN
# 540635  NaN 2022-02-10 20:13:00       NaN        NaN  NaN  NaN
# 540636  NaN 2022-02-10 21:13:00       NaN        NaN  NaN  NaN
#
#         pagobuoy_max_wh  pagobuoy_sig_wh  pagobuoy_mean_wh  stn  \
# 1580                NaN              NaN               NaN  NaN
# 1581                NaN              NaN               NaN  NaN
# ...

# %%
df3 = df2.fillna(method= 'ffill').fillna(method='bfill')

# %%
df3[df3['value'].isnull()]
# Out:
# Empty DataFrame
# Columns: [num, time, latitude, longitude, sog, cog, pagobuoy_max_wh, pagobuoy_sig_wh, pagobuoy_mean_wh, stn, lightbecon_wd, lightbecon_ws, buoy_ws, buoy_wd, answer, location, value]
# Index: []

# %% [markdown]
# ## 이로써 발생한 시계열 간의 차이에 대해 새로운 값들을 만들어 주었고 이들에 대한 값은 fillna 와 bfillna로 채워주었다. 약 1000개의 데이터르 새로 만들어 주었다.
